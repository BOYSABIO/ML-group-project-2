# %% [markdown]
# # Group 8 ML Project: Predicting Hotel Reservation Cancellations

# %%
import pandas as pd
import numpy as np

from sklearn.decomposition import PCA   
import seaborn as sns 
import matplotlib.pyplot as plt
from feature_engine.encoding import RareLabelEncoder, OrdinalEncoder
from sklearn.metrics import accuracy_score

import openpyxl

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Import the data and do some data processing

# %%
# Read data
filename = 'Hotel_Reservations.csv'
df = pd.read_csv(filename) #it has two sheets, we load the 2nd one
df.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# 1        Room_Type 1          5          2018             11             6
# 2        Room_Type 1          1          2018              2            28
# 3        Room_Type 1        211          2018              5            20
# 4        Room_Type 1         48          2018              4            11
#
#   market_segment_type  repeated_guest  no_of_previous_cancellations  \
# 0             Offline               0                             0
# 1              Online               0                             0
# 2              Online               0                             0
# 3              Online               0                             0
# 4              Online               0                             0
#
#    no_of_previous_bookings_not_canceled  avg_price_per_room  \
# 0                                     0               65.00
# 1                                     0              106.68
# 2                                     0               60.00
# 3                                     0              100.00
# 4                                     0               94.50
#
#    no_of_special_requests booking_status
# 0                       0   Not_Canceled
# 1                       1   Not_Canceled
# 2                       0       Canceled
# 3                       0       Canceled
# 4                       0       Canceled

# %% [markdown]
# We first need to remove useless variables and null values (or impute them) since KNN in scikit does not handle them. In this case there are no useless variables to discard, so we will check for nulls.

# %%
df.isnull().sum()
# Out:
# Booking_ID                              0
# no_of_adults                            0
# no_of_children                          0
# no_of_weekend_nights                    0
# no_of_week_nights                       0
# type_of_meal_plan                       0
# required_car_parking_space              0
# room_type_reserved                      0
# lead_time                               0
# arrival_year                            0
# arrival_month                           0
# arrival_date                            0
# market_segment_type                     0
# repeated_guest                          0
# no_of_previous_cancellations            0
# no_of_previous_bookings_not_canceled    0
# avg_price_per_room                      0
# no_of_special_requests                  0
# booking_status                          0
# dtype: int64

# %% [markdown]
# Since there are no null values, we can proceed with the data cleaning

# %%
#We set the Booking ID as the index - so we can then keep track of each booking
df.set_index('Booking_ID', inplace=True)

# %% [markdown]
# We check for all unique values in categorical variables to see if we should conduct one-hot encoding or convert to numerical (if the categories are ordinal)

# %%
#Check for all unique values in market_segment_type
df['market_segment_type'].unique()
# Out:
# array(['Offline', 'Online', 'Corporate', 'Aviation', 'Complementary'],
#       dtype=object)

# %%
#Check for all unique values in room_type_reserved
df['room_type_reserved'].unique()
# Out:
# array(['Room_Type 1', 'Room_Type 4', 'Room_Type 2', 'Room_Type 6',
#        'Room_Type 5', 'Room_Type 7', 'Room_Type 3'], dtype=object)

# %%
#Check for all unique values in type_of_meal_plan
df['type_of_meal_plan'].unique()
# Out:
# array(['Meal Plan 1', 'Not Selected', 'Meal Plan 2', 'Meal Plan 3'],
#       dtype=object)

# %% [markdown]
# We will proceed with one-hot encoding of market_segment_type and type_of_meal_plan, while convering room_type_reserved values to numbers assuming that the room types are ordinal and the distance between Room Type 1 and Room Type 4 should not be the same.

# %%
# One-hot encoding
df = pd.get_dummies(df, columns=['market_segment_type'], prefix='segment')

# Display the first few rows
df.head()
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN00001               2               0                     1
# INN00002               2               0                     2
# INN00003               1               0                     2
# INN00004               2               0                     0
# INN00005               2               0                     1
#
#             no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# Booking_ID
# INN00001                    2       Meal Plan 1                           0
# INN00002                    3      Not Selected                           0
# INN00003                    1       Meal Plan 1                           0
# INN00004                    2       Meal Plan 1                           0
# INN00005                    1      Not Selected                           0
#
#            room_type_reserved  lead_time  arrival_year  arrival_month  ...  \
# Booking_ID                                                             ...
# INN00001          Room_Type 1        224          2017             10  ...
# INN00002          Room_Type 1          5          2018             11  ...
# INN00003          Room_Type 1          1          2018              2  ...
# INN00004          Room_Type 1        211          2018              5  ...
# INN00005          Room_Type 1         48          2018              4  ...
#
#             no_of_previous_cancellations  \
# Booking_ID
# INN00001                               0
# INN00002                               0
# INN00003                               0
# INN00004                               0
# INN00005                               0
#
#             no_of_previous_bookings_not_canceled  avg_price_per_room  \
# Booking_ID
# INN00001                                       0               65.00
# INN00002                                       0              106.68
# INN00003                                       0               60.00
# INN00004                                       0              100.00
# INN00005                                       0               94.50
#
#             no_of_special_requests  booking_status  segment_Aviation  \
# Booking_ID
# INN00001                         0    Not_Canceled             False
# INN00002                         1    Not_Canceled             False
# INN00003                         0        Canceled             False
# INN00004                         0        Canceled             False
# INN00005                         0        Canceled             False
#
#            segment_Complementary  segment_Corporate  segment_Offline  \
# Booking_ID
# INN00001                   False              False             True
# INN00002                   False              False            False
# INN00003                   False              False            False
# INN00004                   False              False            False
# INN00005                   False              False            False
#
#             segment_Online
# Booking_ID
# INN00001             False
# INN00002              True
# INN00003              True
# INN00004              True
# INN00005              True
#
# [5 rows x 22 columns]

# %%
# One-hot encoding for 'type_of_meal_plan'
df = pd.get_dummies(df, columns=['type_of_meal_plan'], prefix='meal_plan')

# Display the first few rows
df.head()
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN00001               2               0                     1
# INN00002               2               0                     2
# INN00003               1               0                     2
# INN00004               2               0                     0
# INN00005               2               0                     1
#
#             no_of_week_nights  required_car_parking_space room_type_reserved  \
# Booking_ID
# INN00001                    2                           0        Room_Type 1
# INN00002                    3                           0        Room_Type 1
# INN00003                    1                           0        Room_Type 1
# INN00004                    2                           0        Room_Type 1
# INN00005                    1                           0        Room_Type 1
#
#             lead_time  arrival_year  arrival_month  arrival_date  ...  \
# Booking_ID                                                        ...
# INN00001          224          2017             10             2  ...
# INN00002            5          2018             11             6  ...
# INN00003            1          2018              2            28  ...
# INN00004          211          2018              5            20  ...
# INN00005           48          2018              4            11  ...
#
#             booking_status  segment_Aviation  segment_Complementary  \
# Booking_ID
# INN00001      Not_Canceled             False                  False
# INN00002      Not_Canceled             False                  False
# INN00003          Canceled             False                  False
# INN00004          Canceled             False                  False
# INN00005          Canceled             False                  False
#
#             segment_Corporate  segment_Offline segment_Online  \
# Booking_ID
# INN00001                False             True          False
# INN00002                False            False           True
# INN00003                False            False           True
# INN00004                False            False           True
# INN00005                False            False           True
#
#             meal_plan_Meal Plan 1  meal_plan_Meal Plan 2  \
# Booking_ID
# INN00001                     True                  False
# INN00002                    False                  False
# INN00003                     True                  False
# INN00004                     True                  False
# INN00005                    False                  False
#
#             meal_plan_Meal Plan 3  meal_plan_Not Selected
# Booking_ID
# INN00001                    False                   False
# INN00002                    False                    True
# INN00003                    False                   False
# INN00004                    False                   False
# INN00005                    False                    True
#
# [5 rows x 25 columns]

# %%
# Extract the numerical part from 'Room_Type X' -- since we assume that the room types are ordinal
df['room_type_reserved'] = df['room_type_reserved'].str.extract('(\d+)').astype(int)

# Display unique values after transformation
df['room_type_reserved'].unique()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\SABIO\AppData\Local\Temp\ipykernel_36272\777233012.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df['room_type_reserved'] = df['room_type_reserved'].str.extract('(\d+)').astype(int)
# array([1, 4, 2, 6, 5, 7, 3])

# %% [markdown]
# We will also create a binary target variable "booking_canceled" determining whether the booking was cancelled or not

# %%
df['booking_canceled'] = df['booking_status'].replace({'Canceled': 1, 'Not_Canceled': 0})

# Display unique values after transformation
df['booking_canceled'].unique()
# Out:
# C:\Users\SABIO\AppData\Local\Temp\ipykernel_36272\2682574745.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['booking_canceled'] = df['booking_status'].replace({'Canceled': 1, 'Not_Canceled': 0})
# array([0, 1])

# %%
df.drop(columns=['booking_status'], inplace=True)

# %%
#Features left for analysis 
df.columns
# Out:
# Index(['no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'required_car_parking_space', 'room_type_reserved',
#        'lead_time', 'arrival_year', 'arrival_month', 'arrival_date',
#        'repeated_guest', 'no_of_previous_cancellations',
#        'no_of_previous_bookings_not_canceled', 'avg_price_per_room',
#        'no_of_special_requests', 'segment_Aviation', 'segment_Complementary',
#        'segment_Corporate', 'segment_Offline', 'segment_Online',
#        'meal_plan_Meal Plan 1', 'meal_plan_Meal Plan 2',
#        'meal_plan_Meal Plan 3', 'meal_plan_Not Selected', 'booking_canceled'],
#       dtype='object')

# %% [markdown]
# ## Exploratory Data Analysis (EDA) of the Hotel Reservations dataset

# %%
#Exploratory data analysis
df.describe()
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# count  36275.000000    36275.000000          36275.000000       36275.000000
# mean       1.844962        0.105279              0.810724           2.204300
# std        0.518715        0.402648              0.870644           1.410905
# min        0.000000        0.000000              0.000000           0.000000
# 25%        2.000000        0.000000              0.000000           1.000000
# 50%        2.000000        0.000000              1.000000           2.000000
# 75%        2.000000        0.000000              2.000000           3.000000
# max        4.000000       10.000000              7.000000          17.000000
#
#        required_car_parking_space  room_type_reserved     lead_time  \
# count                36275.000000        36275.000000  36275.000000
# mean                     0.030986            1.708890     85.232557
# std                      0.173281            1.399851     85.930817
# min                      0.000000            1.000000      0.000000
# 25%                      0.000000            1.000000     17.000000
# 50%                      0.000000            1.000000     57.000000
# 75%                      0.000000            1.000000    126.000000
# max                      1.000000            7.000000    443.000000
#
#        arrival_year  arrival_month  arrival_date  repeated_guest  \
# count  36275.000000   36275.000000  36275.000000    36275.000000
# mean    2017.820427       7.423653     15.596995        0.025637
# std        0.383836       3.069894      8.740447        0.158053
# min     2017.000000       1.000000      1.000000        0.000000
# 25%     2018.000000       5.000000      8.000000        0.000000
# 50%     2018.000000       8.000000     16.000000        0.000000
# 75%     2018.000000      10.000000     23.000000        0.000000
# max     2018.000000      12.000000     31.000000        1.000000
#
#        no_of_previous_cancellations  no_of_previous_bookings_not_canceled  \
# count                  36275.000000                          36275.000000
# mean                       0.023349                              0.153411
# std                        0.368331                              1.754171
# min                        0.000000                              0.000000
# 25%                        0.000000                              0.000000
# 50%                        0.000000                              0.000000
# 75%                        0.000000                              0.000000
# max                       13.000000                             58.000000
#
#        avg_price_per_room  no_of_special_requests  booking_canceled
# count        36275.000000            36275.000000      36275.000000
# mean           103.423539                0.619655          0.327636
# std             35.089424                0.786236          0.469358
# min              0.000000                0.000000          0.000000
# 25%             80.300000                0.000000          0.000000
# 50%             99.450000                0.000000          0.000000
# 75%            120.000000                1.000000          1.000000
# max            540.000000                5.000000          1.000000

# %% [markdown]
# Very important to **standardize** the data!

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

target = df["booking_canceled"] #we select the target variable before standardizing the data

columns = df.columns
standard_scaler = StandardScaler()
data = pd.DataFrame(standard_scaler.fit_transform(df), columns=df.columns)
data

#min_max_scaler = MinMaxScaler() - Another option
#data = min_max_scaler.fit_transform(data)
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0          0.298893        -0.26147              0.217401          -0.144803
# 1          0.298893        -0.26147              1.365993           0.563972
# 2         -1.628975        -0.26147              1.365993          -0.853578
# 3          0.298893        -0.26147             -0.931190          -0.144803
# 4          0.298893        -0.26147              0.217401          -0.853578
# ...             ...             ...                   ...                ...
# 36270      2.226761        -0.26147              1.365993           2.690296
# 36271      0.298893        -0.26147              0.217401           0.563972
# 36272      0.298893        -0.26147              1.365993           2.690296
# 36273      0.298893        -0.26147             -0.931190           0.563972
# 36274      0.298893        -0.26147              0.217401          -0.144803
#
#        required_car_parking_space  room_type_reserved  lead_time  \
# 0                       -0.178819           -0.506411   1.614896
# 1                       -0.178819           -0.506411  -0.933701
# 2                       -0.178819           -0.506411  -0.980250
# 3                       -0.178819           -0.506411   1.463610
# 4                       -0.178819           -0.506411  -0.433291
# ...                           ...                 ...        ...
# 36270                   -0.178819            1.636704  -0.002706
# 36271                   -0.178819           -0.506411   1.661446
# 36272                   -0.178819           -0.506411   0.730452
# 36273                   -0.178819           -0.506411  -0.258730
# 36274                   -0.178819           -0.506411   1.417060
#
#        arrival_year  arrival_month  arrival_date  ...  segment_Aviation  \
# 0         -2.137469       0.839242     -1.555662  ...         -0.058803
# 1          0.467843       1.164990     -1.098013  ...         -0.058803
# 2          0.467843      -1.766747      1.419055  ...         -0.058803
# 3          0.467843      -0.789501      0.503757  ...         -0.058803
# 4          0.467843      -1.115250     -0.525952  ...         -0.058803
# ...             ...            ...           ...  ...               ...
# 36270      0.467843       0.187744     -1.441250  ...         -0.058803
# 36271      0.467843       0.839242      0.160521  ...         -0.058803
# 36272      0.467843      -0.138004     -1.670074  ...         -0.058803
# 36273      0.467843      -1.115250      0.618170  ...         -0.058803
# 36274      0.467843       1.490739      1.647879  ...         -0.058803
#
#        segment_Complementary  segment_Corporate  segment_Offline  \
# 0                  -0.104385          -0.242645         1.563833
# 1                  -0.104385          -0.242645        -0.639454
# 2                  -0.104385          -0.242645        -0.639454
# 3                  -0.104385          -0.242645        -0.639454
# 4                  -0.104385          -0.242645        -0.639454
# ...                      ...                ...              ...
# 36270              -0.104385          -0.242645        -0.639454
# 36271              -0.104385          -0.242645        -0.639454
# 36272              -0.104385          -0.242645        -0.639454
# 36273              -0.104385          -0.242645        -0.639454
# 36274              -0.104385          -0.242645         1.563833
#
#        segment_Online  meal_plan_Meal Plan 1  meal_plan_Meal Plan 2  \
# 0           -1.333174               0.550650              -0.316611
# 1            0.750090              -1.816036              -0.316611
# 2            0.750090               0.550650              -0.316611
# 3            0.750090               0.550650              -0.316611
# 4            0.750090              -1.816036              -0.316611
# ...               ...                    ...                    ...
# 36270        0.750090               0.550650              -0.316611
# 36271        0.750090               0.550650              -0.316611
# 36272        0.750090               0.550650              -0.316611
# 36273        0.750090              -1.816036              -0.316611
# 36274       -1.333174               0.550650              -0.316611
#
#        meal_plan_Meal Plan 3  meal_plan_Not Selected  booking_canceled
# 0                  -0.011741               -0.405849         -0.698062
# 1                  -0.011741                2.463970         -0.698062
# 2                  -0.011741               -0.405849          1.432539
# 3                  -0.011741               -0.405849          1.432539
# 4                  -0.011741                2.463970          1.432539
# ...                      ...                     ...               ...
# 36270              -0.011741               -0.405849         -0.698062
# 36271              -0.011741               -0.405849          1.432539
# 36272              -0.011741               -0.405849         -0.698062
# 36273              -0.011741                2.463970          1.432539
# 36274              -0.011741               -0.405849         -0.698062
#
# [36275 rows x 25 columns]

# %% [markdown]
# And show pie chart with classes

# %%
unique, counts = np.unique(target, return_counts=True)
plt.pie(counts, labels=unique, autopct='%.0f%%');

# %%
# Heatmap to show correlation between explanatory variables
sns.set(font_scale=1.1)
fig, ax = plt.subplots(figsize=(8,8))         # Sample figsize in inches
sns.heatmap(df.corr(), annot=True, fmt=".2f", linewidths=1, ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# We analyzed feature importance to understand the most relevant factors influencing hotel reservation cancellations.

# %%
#TO DO

# %% [markdown]
# ##  Random Forest Classifier with Bagging

# %% [markdown]
# #### Train-Test Split

# %%
# Import required libraries

from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
#split data into train and test set
x_train, x_test, y_train, y_test = train_test_split(df.iloc[:,df.columns != 'booking_canceled'],
                                                    df["booking_canceled"],
                                                    test_size=0.25, 
                                                    random_state=100)

# %%
print("Train: ", x_train.shape)
print("Test: ", x_test.shape)
# Out:
# Train:  (29020, 24)
# Test:  (7255, 24)

# %%
RF = RandomForestClassifier(n_estimators = 200,  
                              random_state = 0, 
                              n_jobs = -1, 
                              oob_score = True)

# %%
RF = RandomForestClassifier(
    n_estimators=200,  
    random_state=0, 
    n_jobs=-1, 
    oob_score=True
)

# %%
# Train the model on training data

RF.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=200, n_jobs=-1, oob_score=True,
#                        random_state=0)

# %%
# Make predictions on the test set
y_pred_test = RF.predict(x_test)

# %% [markdown]
# The purpose of using GridSearchCV is to find the best combination of hyperparameters for your Random Forest (RF) model to improve its performance.

# %%
param_grid = {
    'min_samples_leaf' :[1,3,5], 
    'max_features' : [10,15,20,25,30],
    'criterion' : ['gini','entropy'] 
}

# %%
import time 
start_time = time.time()

from sklearn.model_selection import GridSearchCV
cvRF = GridSearchCV(estimator=RF, param_grid=param_grid, cv=5, scoring='roc_auc')  #estimator=RF: Uses the Random Forest model (RF) as the base estimator.

cvRF.fit(x_train,y_train)
print ("Completed in {:0.0f} seconds ".format((time.time() - start_time)))
# Out:
# Completed in 213 seconds

# %%
#shows the best combination of criteria found

print("Best Parameters:", cvRF.best_params_)
print("Best ROC-AUC Score:", cvRF.best_score_)
# Out:
# Best Parameters: {'criterion': 'entropy', 'max_features': 10, 'min_samples_leaf': 1}
# Best ROC-AUC Score: 0.9560978195039563

# %% [markdown]
# fitting the random forest with best combination

# %%
RF = RandomForestClassifier(
    n_estimators=200,              
    criterion='entropy',            # Best criterion found
    max_features=10,                # Best max_features found
    min_samples_leaf=1,             # Best min_samples_leaf found
    random_state=0,                
    n_jobs=-1,                      
    oob_score=True                  # Enable out-of-bag score for bagging
)

# %%
# Fit the model to your training data
RF.fit(x_train, y_train)
# Out:
# OOB Score: 0.9027567195037904

# %% [markdown]
# **Feature Importance to Understand What Influences Cancellations Most:**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

feature_importances = pd.Series(RF.feature_importances_, index=x_train.columns)
top_features = feature_importances.sort_values(ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_features.values, y=top_features.index)
plt.xlabel("Feature Importance Score")
plt.ylabel("Features")
plt.title("Top 10 Most Important Features for Hotel Cancellations")
plt.show()

# %%
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred_test)
conf_matrix = confusion_matrix(y_test, y_pred_test)
class_report = classification_report(y_test, y_pred_test)
oob_score = RF.oob_score_  # Out-of-Bag accuracy

# %%
# Display results
print(f"Model Accuracy: {accuracy:.4f}")
print(f"OOB Score: {oob_score:.4f}")
print("\nConfusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
# Out:
# Model Accuracy: 0.9078
# OOB Score: 0.9028
#
# Confusion Matrix:
# [[4668  230]
#  [ 439 1918]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93      4898
#            1       0.89      0.81      0.85      2357
#
#     accuracy                           0.91      7255
#    macro avg       0.90      0.88      0.89      7255
# weighted avg       0.91      0.91      0.91      7255

# %% [markdown]
# The model achieved 90.78% accuracy, meaning it correctly predicts cancellations in most cases.
#
# The OOB score is 90.00%, confirming that the model generalizes well to unseen data without needing extra validation data.

# %%
# Show confusion matrix using heatmap
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=["Not Canceled", "Canceled"], yticklabels=["Not Canceled", "Canceled"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix for Random Forest")
plt.show()

# %% [markdown]
# ## Random Forest Model to predict hotel reservation cancellations - LOUIS-ESMEL

# %%
#TO DO

# %% [markdown]
# ## Boosting Model to predict hotel reservation cancellations - SPENCER

# %%
#TO DO

# %%
df.head(3)
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN00001               2               0                     1
# INN00002               2               0                     2
# INN00003               1               0                     2
#
#             no_of_week_nights  required_car_parking_space  room_type_reserved  \
# Booking_ID
# INN00001                    2                           0                   1
# INN00002                    3                           0                   1
# INN00003                    1                           0                   1
#
#             lead_time  arrival_year  arrival_month  arrival_date  ...  \
# Booking_ID                                                        ...
# INN00001          224          2017             10             2  ...
# INN00002            5          2018             11             6  ...
# INN00003            1          2018              2            28  ...
#
#             segment_Aviation  segment_Complementary  segment_Corporate  \
# Booking_ID
# INN00001               False                  False              False
# INN00002               False                  False              False
# INN00003               False                  False              False
#
#             segment_Offline  segment_Online  meal_plan_Meal Plan 1  \
# Booking_ID
# INN00001               True           False                   True
# INN00002              False            True                  False
# INN00003              False            True                   True
#
#             meal_plan_Meal Plan 2  meal_plan_Meal Plan 3  \
# Booking_ID
# INN00001                    False                  False
# INN00002                    False                  False
# INN00003                    False                  False
#
#             meal_plan_Not Selected  booking_canceled
# Booking_ID
# INN00001                     False                 0
# INN00002                      True                 0
# INN00003                     False                 1
#
# [3 rows x 25 columns]

# %% [markdown]
# Some extra feature engineering

# %%
def categorize_lead_time(x):
    if x < 7:
        return 'Short'
    elif x <= 30:
        return 'Medium'
    else:
        return 'Long'

# %%
df_copy = df.copy()

df_copy['total_nights'] = df_copy['no_of_week_nights'] + df_copy['no_of_weekend_nights']
df_copy['total_guests'] = df_copy['no_of_adults'] + df_copy['no_of_children']
df_copy['lead_time_bucket'] = df_copy['lead_time'].apply(categorize_lead_time)

peak_months = [6, 7, 8, 12]  # June, July, August, December
df_copy['is_peak_season'] = df_copy['arrival_month'].apply(lambda x: 1 if x in peak_months else 0)

# %%
df_copy.head(3)
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN00001               2               0                     1
# INN00002               2               0                     2
# INN00003               1               0                     2
#
#             no_of_week_nights  required_car_parking_space  room_type_reserved  \
# Booking_ID
# INN00001                    2                           0                   1
# INN00002                    3                           0                   1
# INN00003                    1                           0                   1
#
#             lead_time  arrival_year  arrival_month  arrival_date  ...  \
# Booking_ID                                                        ...
# INN00001          224          2017             10             2  ...
# INN00002            5          2018             11             6  ...
# INN00003            1          2018              2            28  ...
#
#             segment_Online  meal_plan_Meal Plan 1  meal_plan_Meal Plan 2  \
# Booking_ID
# INN00001             False                   True                  False
# INN00002              True                  False                  False
# INN00003              True                   True                  False
#
#             meal_plan_Meal Plan 3  meal_plan_Not Selected  booking_canceled  \
# Booking_ID
# INN00001                    False                   False                 0
# INN00002                    False                    True                 0
# INN00003                    False                   False                 1
#
#             total_nights  total_guests  lead_time_bucket  is_peak_season
# Booking_ID
# INN00001               3             2              Long               0
# INN00002               5             2             Short               0
# INN00003               3             1             Short               0
#
# [3 rows x 29 columns]

# %%
from sklearn.model_selection import train_test_split

X = df.drop(columns=['booking_canceled'])
y = df['booking_canceled']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.5, random_state= 123)

# %%
from sklearn.model_selection import train_test_split

X, y = df_copy.iloc[:,df_copy.columns != 'booking_canceled'], df_copy["booking_canceled"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.5, random_state= 123)

# %% [markdown]
# DMatrix for Cross Validation (Optimally store datasets in XGBoost)

# %%
import xgboost as xgb

data_dmatrix = xgb.DMatrix(data=X, label=y)

xg_model = xgb.XGBClassifier(n_estimators=20, eval_metric='logloss')
xg_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=20,
#               n_jobs=None, num_parallel_tree=None, random_state=None, ...)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score

# Predict on train and test
y_train_pred = xg_model.predict(X_train)
y_test_pred = xg_model.predict(X_test)

# Predict probabilities for ROC AUC
y_test_probs = xg_model.predict_proba(X_test)[:, 1]

# Evaluate
print("Train Accuracy:", accuracy_score(y_train, y_train_pred))
print("Test Accuracy:", accuracy_score(y_test, y_test_pred))
print("\nClassification Report (Test):")
print(classification_report(y_test, y_test_pred))
print("Confusion Matrix (Test):")
print(confusion_matrix(y_test, y_test_pred))
print("ROC AUC Score (Test):", roc_auc_score(y_test, y_test_probs))
# Out:
# Train Accuracy: 0.8807410266306446
# Test Accuracy: 0.8732495313706031
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91     12286
#            1       0.84      0.75      0.79      5852
#
#     accuracy                           0.87     18138
#    macro avg       0.86      0.84      0.85     18138
# weighted avg       0.87      0.87      0.87     18138
#
# Confusion Matrix (Test):
# [[11478   808]
#  [ 1491  4361]]
# ROC AUC Score (Test): 0.9362483113500532

# %%
xgb.plot_importance(xg_model, importance_type="weight")
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# Hyperparameters

# %%
params = {
    'objective':'binary:logistic', 
    'colsample_bytree':0.3, 
    'learning_rate':0.1, 
    'max_depth':5,
    'alpha':10,
    'eval_metric':['auc', 'logloss', 'error']
}

cv_results = xgb.cv(
    dtrain = data_dmatrix, 
    params = params, 
    nfold = 3, 
    num_boost_round = 200, 
    early_stopping_rounds = 5,
    as_pandas = True, 
    seed=123)

cv_results.head()
# Out:
#    train-auc-mean  train-auc-std  train-logloss-mean  train-logloss-std  \
# 0        0.805883       0.000807            0.607425           0.001433
# 1        0.808142       0.000926            0.604600           0.001423
# 2        0.816875       0.001277            0.584946           0.001534
# 3        0.827519       0.001274            0.578336           0.001727
# 4        0.871676       0.001150            0.564038           0.001869
#
#    train-error-mean  train-error-std  test-auc-mean  test-auc-std  \
# 0          0.327636         0.002031       0.802078      0.001698
# 1          0.327636         0.002031       0.803017      0.001068
# 2          0.327636         0.002031       0.811961      0.000090
# 3          0.327636         0.002031       0.821747      0.001108
# 4          0.325362         0.003869       0.866641      0.001465
#
#    test-logloss-mean  test-logloss-std  test-error-mean  test-error-std
# 0           0.607735          0.002676         0.327636        0.004062
# 1           0.605077          0.002648         0.327636        0.004062
# 2           0.585751          0.002730         0.327636        0.004062
# 3           0.579323          0.002579         0.327636        0.004062
# 4           0.565137          0.002543         0.325265        0.002006

# %%
best = cv_results['test-auc-mean'].max()
best_round = cv_results['test-auc-mean'].idxmax()

print(f"Best AUC: {best:.4f} at round {best_round}")
# Out:
# Best AUC: 0.9071 at round 38

# %%
best = cv_results['test-error-mean'].min()
best_round = cv_results['test-error-mean'].idxmin()

print(f"Lowest Error: {best:.4f} at round {best_round}")
# Out:
# Lowest Error: 0.1582 at round 38

# %%
best = cv_results['test-logloss-mean'].min()
best_round = cv_results['test-logloss-mean'].idxmin()

print(f"Lowest Logloss: {best:.4f} at round {best_round}")
# Out:
# Lowest Logloss: 0.4061 at round 38

# %% [markdown]
# Hyperparameter Tuning (Grid Search)

# %%
from sklearn.model_selection import GridSearchCV

gbm_param_grid = {
    'learning_rate': [0.01, 0.1, 0.2],
    'subsample': [0.3, 0.5, 0.7],
    'max_depth': [3, 5, 7],
    'colsample_bytree': [0.3, 0.7],
    'n_estimators': [50, 100]
}

gbm = xgb.XGBClassifier() # evaluation metric is logloss by default

grid_search = GridSearchCV(
    estimator=gbm,
    param_grid=gbm_param_grid,
    scoring='roc_auc',   #'roc_auc', 'f1'
    cv=5,
    verbose=2
)

grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.3; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.7; total time=   0.1s
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=None, ...),
#              param_grid={'colsample_bytree': [0.3, 0.7],
#                          'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [3, 5, 7], 'n_estimators': [50, 100],
#                          'subsample': [0.3, 0.5, 0.7]},
#              scoring='roc_auc', verbose=2)

# %%
print("Best Parameters:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)
# Out:
# Best Parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.2, 'max_depth': 7, 'n_estimators': 100, 'subsample': 0.7}
# Best Score: 0.9523749017464933

# %% [markdown]
# Best Model

# %%
best_model = xgb.XGBClassifier(
    learning_rate=0.2,
    max_depth=7,
    colsample_bytree=0.7,
    subsample=0.7,
    n_estimators=100,
    eval_metric='logloss'
)

best_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.7, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.2, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=7,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, random_state=None, ...)

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

y_pred = best_model.predict(X_test)
y_probs = best_model.predict_proba(X_test)[:, 1]

# %% [markdown]
# Vizualize the Tree

# %%
from xgboost import plot_tree
import matplotlib.pyplot as plt
import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin'

from io import StringIO
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

plt.figure(figsize=(20, 10))
plot_tree(best_model, num_trees=0)  # Change num_trees to see different trees in the ensemble
plt.title("XGBoost - Tree 0")
plt.show()

# %% [markdown]
# Confusion Matrix

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix

conf_mat = confusion_matrix(y_test, y_pred)

fig, ax = plt.subplots()
label_names = ['TN','FN','FP','TP']
label_counts = ['{0:0.0f}'.format(value) for value in conf_mat.flatten()]
labels = [f'{v1}\n{v2}' for v1, v2 in zip(label_names,label_counts)]
labels = np.asarray(labels).reshape(2,2)

# Draw heatmap using confusion matrix
sns.heatmap(conf_mat, annot=labels, fmt='')
ax.set_title('Confusion matrix')
ax.set_xlabel('Actual Values')
ax.set_ylabel('Predicted Values');

# %% [markdown]
# ROC Curve

# %%
from sklearn.metrics import roc_curve, auc

prob_pred = best_model.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, prob_pred)
roc_auc = auc(fpr, tpr)  
optimal_idx = np.argmax(tpr - fpr)  # Best trade-off between TPR and FPR
optimal_threshold = thresholds[optimal_idx]
print(f"Threshold óptimo: {optimal_threshold:.2f}")

# ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Random classification

# Highlight optimal threshold 
plt.scatter(fpr[optimal_idx], tpr[optimal_idx], color='red', marker='o',
            label=f'Optimal Threshold = {optimal_threshold:.2f}')

plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# Threshold óptimo: 0.30

# %% [markdown]
# ## KNN Model to predict hotel reservation cancellations

# %% [markdown]
# Now we create a function to do the data splitting, that we will use in a short while

# %%
from sklearn.model_selection import train_test_split 

# Train and test sets
def split_data(data, ratio):
    X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=ratio, stratify=target)
    X_train.drop('booking_canceled', axis=1, inplace=True)
    X_test.drop('booking_canceled', axis=1, inplace=True)
    return X_train, X_test, y_train, y_test

# %% [markdown]
# ^^ Stratify is used to create balanced samples around the target variable

# %% [markdown]
# ### KNN model 1

# %% [markdown]
# First example with k=5

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_classifier = KNeighborsClassifier(n_neighbors=5) # we don´t know yet the optimal number of neighbours

X_train, X_test, y_train, y_test = split_data(data, 0.2) 
print(X_train.shape)
print(X_test.shape)
# Out:
# (29020, 24)
# (7255, 24)

# %%
knn_classifier.fit(X_train, y_train)

# Predictions (on test set, obviously)
knn_predictions = knn_classifier.predict(X_test)

# Calculate error_rate and print it
error_rate = 1 - accuracy_score(y_test, knn_predictions)
print("% Error (k=5): {0:.1%}".format(error_rate))
# Out:
# % Error (k=5): 15.1%

# %% [markdown]
# ### Look for best option of  k (manually)

# %% [markdown]
# The idea now is to compare different splits and k values (hyper parameter), so we need a error measure calculation (1-accuracy), of course on the test set

# %%
def measure_error(num_iterations, K, ratio):
    perf = np.ones(num_iterations)
    for i in range(num_iterations):
        np.random.seed(i)
        X_train, X_test, y_train, y_test = split_data(data, ratio)
        knn_classifier = KNeighborsClassifier(n_neighbors=K)
        knn_classifier.fit(X_train, y_train)
        knn_predictions = knn_classifier.predict(X_test)
        error_rate = 1 - accuracy_score(y_test, knn_predictions)
        perf[i] = error_rate
    return np.mean(perf)

# %% [markdown]
# Now we produce several models, each with a different split between train and test set (from 50% train set to 90%), <BR>with different neighours values (from 5 to 15) and compare the errors of all them.
# <BR>(we run it on 10 iterations to have it quicker, but normally from 50 is best)

# %%
ratios = np.arange(0.5, 1.0, 0.1)
k_values = np.arange(5, 50)

plt.figure(figsize=(10, 8))
plt.xlabel("Neighbours")
plt.ylabel("Mean Error")

for ratio in ratios:
    print("ratio (train set):", np.round(ratio,2))
    mean_error=[]
    for K in k_values:
        error=measure_error(10, K, ratio) #10 iterations
        print("Neighbours:", K, ", error:", np.round(error,4))
        mean_error.append(error)
    
    plt.plot(k_values, mean_error, marker='o', label=f"Ratio {np.round(ratio,2)}")

plt.title("Error on test data set")
plt.legend(title="Ratios for train set")
plt.xticks(k_values)
plt.ylim(0.1, 0.25)
plt.grid(True)
plt.show()
# Out:
# ratio (train set): 0.5
# Neighbours: 5 , error: 0.1596
# Neighbours: 6 , error: 0.1589
# Neighbours: 7 , error: 0.1591
# Neighbours: 8 , error: 0.1603
# Neighbours: 9 , error: 0.1596
# Neighbours: 10 , error: 0.1611
# Neighbours: 11 , error: 0.1616
# Neighbours: 12 , error: 0.1624
# Neighbours: 13 , error: 0.1623
# Neighbours: 14 , error: 0.163
# Neighbours: 15 , error: 0.1637
# Neighbours: 16 , error: 0.1643
# Neighbours: 17 , error: 0.1645
# Neighbours: 18 , error: 0.1661
# Neighbours: 19 , error: 0.1665
# Neighbours: 20 , error: 0.1661
# Neighbours: 21 , error: 0.1663
# Neighbours: 22 , error: 0.1671
# Neighbours: 23 , error: 0.1675
# Neighbours: 24 , error: 0.168
# Neighbours: 25 , error: 0.1683
# Neighbours: 26 , error: 0.168
# Neighbours: 27 , error: 0.1683
# Neighbours: 28 , error: 0.1685
# Neighbours: 29 , error: 0.1688
# Neighbours: 30 , error: 0.1693
# Neighbours: 31 , error: 0.169
# Neighbours: 32 , error: 0.1692
# Neighbours: 33 , error: 0.1694
# Neighbours: 34 , error: 0.1701
# Neighbours: 35 , error: 0.1704
# Neighbours: 36 , error: 0.1707
# Neighbours: 37 , error: 0.171
# Neighbours: 38 , error: 0.1714
# Neighbours: 39 , error: 0.1722
# Neighbours: 40 , error: 0.1721
# Neighbours: 41 , error: 0.1723
# Neighbours: 42 , error: 0.1728
# Neighbours: 43 , error: 0.173
# Neighbours: 44 , error: 0.1735
# Neighbours: 45 , error: 0.1741
# Neighbours: 46 , error: 0.174
# Neighbours: 47 , error: 0.1743
# Neighbours: 48 , error: 0.1748
# Neighbours: 49 , error: 0.1753
# ratio (train set): 0.6
# Neighbours: 5 , error: 0.1645
# Neighbours: 6 , error: 0.1647
# Neighbours: 7 , error: 0.164
# Neighbours: 8 , error: 0.1644
# Neighbours: 9 , error: 0.1648
# Neighbours: 10 , error: 0.1655
# Neighbours: 11 , error: 0.1659
# Neighbours: 12 , error: 0.1673
# Neighbours: 13 , error: 0.1681
# Neighbours: 14 , error: 0.1682
# Neighbours: 15 , error: 0.1682
# Neighbours: 16 , error: 0.1689
# Neighbours: 17 , error: 0.1689
# Neighbours: 18 , error: 0.1691
# Neighbours: 19 , error: 0.1695
# Neighbours: 20 , error: 0.1695
# Neighbours: 21 , error: 0.1697
# Neighbours: 22 , error: 0.1702
# Neighbours: 23 , error: 0.1704
# Neighbours: 24 , error: 0.1707
# Neighbours: 25 , error: 0.171
# Neighbours: 26 , error: 0.1711
# Neighbours: 27 , error: 0.1714
# Neighbours: 28 , error: 0.1715
# Neighbours: 29 , error: 0.1728
# Neighbours: 30 , error: 0.1736
# Neighbours: 31 , error: 0.1733
# Neighbours: 32 , error: 0.1741
# Neighbours: 33 , error: 0.1743
# Neighbours: 34 , error: 0.1748
# Neighbours: 35 , error: 0.1754
# Neighbours: 36 , error: 0.1756
# Neighbours: 37 , error: 0.1755
# Neighbours: 38 , error: 0.1759
# Neighbours: 39 , error: 0.1763
# Neighbours: 40 , error: 0.1762
# Neighbours: 41 , error: 0.1769
# Neighbours: 42 , error: 0.1775
# Neighbours: 43 , error: 0.1776
# Neighbours: 44 , error: 0.1776
# Neighbours: 45 , error: 0.1778
# Neighbours: 46 , error: 0.1789
# Neighbours: 47 , error: 0.1794
# Neighbours: 48 , error: 0.179
# Neighbours: 49 , error: 0.1791
# ratio (train set): 0.7
# Neighbours: 5 , error: 0.1705
# Neighbours: 6 , error: 0.171
# Neighbours: 7 , error: 0.1707
# Neighbours: 8 , error: 0.1706
# Neighbours: 9 , error: 0.1712
# Neighbours: 10 , error: 0.1714
# Neighbours: 11 , error: 0.1718
# Neighbours: 12 , error: 0.1727
# Neighbours: 13 , error: 0.1729
# Neighbours: 14 , error: 0.1734
# Neighbours: 15 , error: 0.1732
# Neighbours: 16 , error: 0.1735
# Neighbours: 17 , error: 0.1729
# Neighbours: 18 , error: 0.173
# Neighbours: 19 , error: 0.1739
# Neighbours: 20 , error: 0.174
# Neighbours: 21 , error: 0.1743
# Neighbours: 22 , error: 0.1752
# Neighbours: 23 , error: 0.1761
# Neighbours: 24 , error: 0.1765
# Neighbours: 25 , error: 0.1771
# Neighbours: 26 , error: 0.1775
# Neighbours: 27 , error: 0.1777
# Neighbours: 28 , error: 0.1783
# Neighbours: 29 , error: 0.1783
# Neighbours: 30 , error: 0.1783
# Neighbours: 31 , error: 0.1787
# Neighbours: 32 , error: 0.1792
# Neighbours: 33 , error: 0.1799
# Neighbours: 34 , error: 0.1805
# Neighbours: 35 , error: 0.1805
# Neighbours: 36 , error: 0.1811
# Neighbours: 37 , error: 0.1812
# Neighbours: 38 , error: 0.1816
# Neighbours: 39 , error: 0.1814
# Neighbours: 40 , error: 0.1818
# Neighbours: 41 , error: 0.1815
# Neighbours: 42 , error: 0.1826
# Neighbours: 43 , error: 0.1824
# Neighbours: 44 , error: 0.1834
# Neighbours: 45 , error: 0.1831
# Neighbours: 46 , error: 0.1835
# Neighbours: 47 , error: 0.1835
# Neighbours: 48 , error: 0.1844
# Neighbours: 49 , error: 0.1839
# ratio (train set): 0.8
# Neighbours: 5 , error: 0.179
# Neighbours: 6 , error: 0.179
# Neighbours: 7 , error: 0.178
# Neighbours: 8 , error: 0.1789
# Neighbours: 9 , error: 0.1782
# Neighbours: 10 , error: 0.1782
# Neighbours: 11 , error: 0.1782
# Neighbours: 12 , error: 0.1788
# Neighbours: 13 , error: 0.1789
# Neighbours: 14 , error: 0.1801
# Neighbours: 15 , error: 0.1804
# Neighbours: 16 , error: 0.1805
# Neighbours: 17 , error: 0.1812
# Neighbours: 18 , error: 0.1817
# Neighbours: 19 , error: 0.1825
# Neighbours: 20 , error: 0.1827
# Neighbours: 21 , error: 0.1833
# Neighbours: 22 , error: 0.1844
# Neighbours: 23 , error: 0.1846
# Neighbours: 24 , error: 0.185
# Neighbours: 25 , error: 0.1858
# Neighbours: 26 , error: 0.1856
# Neighbours: 27 , error: 0.1853
# Neighbours: 28 , error: 0.1861
# Neighbours: 29 , error: 0.1861
# Neighbours: 30 , error: 0.1868
# Neighbours: 31 , error: 0.1864
# Neighbours: 32 , error: 0.1876
# Neighbours: 33 , error: 0.1876
# Neighbours: 34 , error: 0.1879
# Neighbours: 35 , error: 0.1879
# Neighbours: 36 , error: 0.1883
# Neighbours: 37 , error: 0.188
# Neighbours: 38 , error: 0.1889
# Neighbours: 39 , error: 0.1878
# Neighbours: 40 , error: 0.1889
# Neighbours: 41 , error: 0.1886
# Neighbours: 42 , error: 0.1891
# Neighbours: 43 , error: 0.1895
# Neighbours: 44 , error: 0.1902
# Neighbours: 45 , error: 0.1893
# Neighbours: 46 , error: 0.1909
# Neighbours: 47 , error: 0.1911
# Neighbours: 48 , error: 0.1921
# Neighbours: 49 , error: 0.1914
# ratio (train set): 0.9
# Neighbours: 5 , error: 0.1947
# Neighbours: 6 , error: 0.1957
# Neighbours: 7 , error: 0.1947
# Neighbours: 8 , error: 0.1955
# Neighbours: 9 , error: 0.1942
# Neighbours: 10 , error: 0.1953
# Neighbours: 11 , error: 0.1965
# Neighbours: 12 , error: 0.1982
# Neighbours: 13 , error: 0.1976
# Neighbours: 14 , error: 0.198
# Neighbours: 15 , error: 0.1973
# Neighbours: 16 , error: 0.1978
# Neighbours: 17 , error: 0.198
# Neighbours: 18 , error: 0.1986
# Neighbours: 19 , error: 0.1975
# Neighbours: 20 , error: 0.1992
# Neighbours: 21 , error: 0.1991
# Neighbours: 22 , error: 0.2004
# Neighbours: 23 , error: 0.2002
# Neighbours: 24 , error: 0.2009
# Neighbours: 25 , error: 0.2004
# Neighbours: 26 , error: 0.2013
# Neighbours: 27 , error: 0.2015
# Neighbours: 28 , error: 0.2029
# Neighbours: 29 , error: 0.2031
# Neighbours: 30 , error: 0.2049
# Neighbours: 31 , error: 0.204
# Neighbours: 32 , error: 0.2057
# Neighbours: 33 , error: 0.2049
# Neighbours: 34 , error: 0.2059
# Neighbours: 35 , error: 0.2062
# Neighbours: 36 , error: 0.2082
# Neighbours: 37 , error: 0.2075
# Neighbours: 38 , error: 0.2079
# Neighbours: 39 , error: 0.2073
# Neighbours: 40 , error: 0.2092
# Neighbours: 41 , error: 0.2089
# Neighbours: 42 , error: 0.2099
# Neighbours: 43 , error: 0.2088
# Neighbours: 44 , error: 0.2095
# Neighbours: 45 , error: 0.2089
# Neighbours: 46 , error: 0.2101
# Neighbours: 47 , error: 0.2097
# Neighbours: 48 , error: 0.2113
# Neighbours: 49 , error: 0.2101

# %% [markdown]
# And we can see that error starts to increase (with best ratio) from 7 neighbours approx.
# <BR>We can apply these values to our model and test

# %%
#take the lowest error combination
knn_classifier = KNeighborsClassifier(n_neighbors=7) 
X_train, X_test, y_train, y_test = split_data(data, 0.5) 
knn_classifier.fit(X_train, y_train)

knn_predictions = knn_classifier.predict(X_test)

error_rate = 1 - accuracy_score(y_test, knn_predictions)
print("% Error (k=8): {0:.1%}".format(error_rate))
# Out:
# % Error (k=8): 15.6%

# %% [markdown]
# ### KNN model 2 (with grid search)

# %% [markdown]
# First you need to search for the optimal train-test split (usually 50%-50%) and then you run the grid search for parameters

# %% [markdown]
# Second model, now we are looking for the best k parameter (from 1 to 12) and also the best weighting scheme from the two available <BR>(it is also possible to customize it in sklearn)

# %%
# Grid search for hyperparameters
from sklearn.model_selection import GridSearchCV

parameters = {
    "n_neighbors": range(1, 12),
    "weights": ["uniform", "distance"] # try with both options
}
gridsearch = GridSearchCV(KNeighborsClassifier(), parameters)
gridsearch.fit(X_train, y_train) 

GridSearchCV(estimator=KNeighborsClassifier(), param_grid=parameters)
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': range(1, 12),
#                          'weights': ['uniform', 'distance']})

# %% [markdown]
# What are the best parameters found in the training dataset?

# %%
gridsearch.best_params_ #includes the weighting scheme
# Out:
# {'n_neighbors': 9, 'weights': 'distance'}

# %% [markdown]
# And obviously we now apply those values found, fit the model and make predictions

# %%
from sklearn.metrics import roc_curve, roc_auc_score, accuracy_score, precision_recall_curve, confusion_matrix, recall_score, precision_score

# Apply prediction 
train_preds_grid = gridsearch.predict(X_train)

gridpredictions = gridsearch.predict(X_test) #probability of being in both groups
error_rate = 1 - accuracy_score(y_test, gridpredictions)
print("% Error (grid search): {0:.1%}".format(error_rate))
# Out:
# % Error (grid search): 13.6%

# %% [markdown]
# ^^ we find the best parameters and then we can use it to predict -- saves automatically

# %% [markdown]
# We now create the ROC curve

# %%
pred_prob = gridsearch.predict_proba(X_test) #probability of being in both groups
prob_1 = [p[1] for p in pred_prob] #probability of being in the survived group

auc = roc_auc_score(y_test, prob_1)

fpr, tpr, thresholds = roc_curve(y_test, prob_1, pos_label=1)

train_acc = round(gridsearch.score(X_train,y_train) * 100,2) #Train Accuracy score
test_acc = round(gridsearch.score(X_test,y_test) * 100,2) #Test Accuracy score
print("Train Accuracy score: ", train_acc, "%")
print("Test Accuracy score: ", test_acc, "%")

# ROC curve
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
ax.plot(fpr, tpr, label="ROC with grid search")
ax.plot([0, 1], [0, 1],linestyle='--', label="Random model") 
ax.set_xlabel("FPR")
ax.set_ylabel("TPR")
ax.set_box_aspect(1)
ax.legend()
plt.show()
# Out:
# Train Accuracy score:  99.45 %
# Test Accuracy score:  86.38 %

# %% [markdown]
# And confusion matrix

# %%
import seaborn as sns
import matplotlib.pyplot as plt

print("Confusion Matrix")
conf_mat = confusion_matrix(y_test, gridpredictions)

# Draw heatmap using confusion matrix
sns.heatmap(conf_mat, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('True labels')
plt.ylabel('Predicted label');
# Out:
# Confusion Matrix

# %% [markdown]
# ^^^by default it uses 50% threshold -- later we will see how to change it

# %% [markdown]
# ### KNN model 3 (bagging classifier)

# %% [markdown]
# In the last model we are implementing some bagging to KNN (using best parameters found with grid search)

# %%
best_k = gridsearch.best_params_["n_neighbors"]
best_weights = gridsearch.best_params_["weights"]

# this is the bagged model we will use
bagged_knn = KNeighborsClassifier( 
    n_neighbors=best_k, weights=best_weights
)

# %% [markdown]
# The method has many options, we are using here BaggingClassifier with 100 estimators

# %%
from sklearn.ensemble import BaggingClassifier

knnbagging_model = BaggingClassifier(bagged_knn, n_estimators=100) 
knnbagging_model.fit(X_train, y_train)
# Out:
# BaggingClassifier(estimator=KNeighborsClassifier(n_neighbors=9,
#                                                  weights='distance'),
#                   n_estimators=100)

# %% [markdown]
# And evaluate results with ROC curve and confusion matrix

# %%
test_preds_grid = knnbagging_model.predict(X_test)

predictions = knnbagging_model.predict(X_test) 
pred_prob = knnbagging_model.predict_proba(X_test) #probability of being in both groups
prob_1 = [p[1] for p in pred_prob] #probability of being in the malign group
auc = roc_auc_score(y_test, prob_1)

fpr, tpr, thresholds = roc_curve(y_test, prob_1, pos_label=1)

train_acc = round(knnbagging_model.score(X_train,y_train) * 100,2) #Train Accuracy score
test_acc = round(knnbagging_model.score(X_test,y_test) * 100,2) #Test Accuracy score
print("Train Accuracy score: ", train_acc, "%")
print("Test Accuracy score: ", test_acc, "%")

# ROC curve
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
ax.plot(fpr, tpr, label="ROC with bagged model")
ax.plot([0, 1], [0, 1],linestyle='--', label="Random model") 
ax.set_xlabel("FPR")
ax.set_ylabel("TPR")
ax.set_box_aspect(1)
ax.legend()
plt.show()
# Out:
# Train Accuracy score:  99.45 %
# Test Accuracy score:  86.54 %

# %% [markdown]
# ^^^didn't improve much using bagging

# %%
print("Confusion Matrix")
conf_mat = confusion_matrix(y_test, predictions)

# Draw heatmap using confusion matrix
sns.heatmap(conf_mat, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('True labels')
plt.ylabel('Predicted label');
# Out:
# Confusion Matrix

# %% [markdown]
# #### And finally, we can change the prediction threshold

# %%
threshold = 0.7  
customized_predictions = (knnbagging_model.predict_proba(X_test)[:,1] >= threshold).astype(int)

# %% [markdown]
# Can you anticipate whether we have more or less positives without executing the following code?

# %%
print("Confusion Matrix")
conf_mat = confusion_matrix(y_test, customized_predictions)

# Draw heatmap using confusion matrix
sns.heatmap(conf_mat, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('True labels')
plt.ylabel('Predicted label');
# Out:
# Confusion Matrix

# %% [markdown]
# ## Conclusions
